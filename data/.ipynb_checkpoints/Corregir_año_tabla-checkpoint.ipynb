# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_csv('nfl_football_team_stats.csv', index_col=0)

# Show dataframe
df.head()
# Out:
#          Date  GameNumber GameLocation                Team  TeamScore  \
# Year
# 2010   9/9/10           1         Away   Minnesota Vikings          9
# 2010   9/9/10           1         Home  New Orleans Saints         14
# 2010  9/12/10           1         Away   Arizona Cardinals         17
# 2010  9/12/10           1         Away     Atlanta Falcons          9
# 2010  9/12/10           1         Away   Carolina Panthers         18
#
#                  Opponent  OppponentScore Result  PassingAttempts  \
# Year
# 2010   New Orleans Saints              14   Loss               27
# 2010    Minnesota Vikings               9    Win               36
# 2010       St. Louis Rams              13    Win               41
# 2010  Pittsburgh Steelers              15   Loss               44
# 2010      New York Giants              31   Loss               35
#
#       PassingCompletions  ...  KickReturnTouchdowns  KickReturnYards  \
# Year                      ...
# ...

# %%
#ver el tipo de dato que es Date
df.dtypes
# Out:
# Date                              object
# GameNumber                         int64
# GameLocation                      object
# Team                              object
# TeamScore                          int64
# Opponent                          object
# OppponentScore                     int64
# Result                            object
# PassingAttempts                    int64
# PassingCompletions                 int64
# PassingInterceptions               int64
# PasserRating                     float64
# PassingSacks                       int64
# PassingSacksYardsLost              int64
# PassingTouchdowns                  int64
# PassingYards                       int64
# ReceivingReceptions                int64
# ReceivingTargets                   int64
# ReceivingTouchdowns                int64
# ReceivingYards                     int64
# RushingAttempts                    int64
# RushingTouchdowns                  int64
# RushingYards                       int64
# ...

# %%
#no existen cambos nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4093 entries, 2010 to 2017
# Data columns (total 41 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Date                           4093 non-null   object
#  1   GameNumber                     4093 non-null   int64
#  2   GameLocation                   4093 non-null   object
#  3   Team                           4093 non-null   object
#  4   TeamScore                      4093 non-null   int64
#  5   Opponent                       4093 non-null   object
#  6   OppponentScore                 4093 non-null   int64
#  7   Result                         4093 non-null   object
#  8   PassingAttempts                4093 non-null   int64
#  9   PassingCompletions             4093 non-null   int64
#  10  PassingInterceptions           4093 non-null   int64
#  11  PasserRating                   4093 non-null   float64
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Date'] = df['Date'].astype('datetime64[ns]')

# %%
df['Year_correct'] = df['Date'].dt.year 
df['Month'] = df['Date'].dt.month

# %%
df.head()
# Out:
#            Date  GameNumber GameLocation                Team  TeamScore  \
# Year
# 2010 2010-09-09           1         Away   Minnesota Vikings          9
# 2010 2010-09-09           1         Home  New Orleans Saints         14
# 2010 2010-09-12           1         Away   Arizona Cardinals         17
# 2010 2010-09-12           1         Away     Atlanta Falcons          9
# 2010 2010-09-12           1         Away   Carolina Panthers         18
#
#                  Opponent  OppponentScore Result  PassingAttempts  \
# Year
# 2010   New Orleans Saints              14   Loss               27
# 2010    Minnesota Vikings               9    Win               36
# 2010       St. Louis Rams              13    Win               41
# 2010  Pittsburgh Steelers              15   Loss               44
# 2010      New York Giants              31   Loss               35
#
#       PassingCompletions  ...  PuntReturnAttempts  PuntReturnTouchdowns  \
# Year                      ...
# ...

# %%
df.to_csv('nfl_football_team_stats_CORRECT_YEAR.csv')
